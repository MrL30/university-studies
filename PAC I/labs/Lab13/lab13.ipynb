# %% [raw]
# ░██                    ░██             ░██    ░██████                ░█████████     ░███      ░██████       ░████     ░██
# ░██                    ░██           ░████   ░██   ░██               ░██     ░██   ░██░██    ░██   ░██     ░██ ░██  ░████
# ░██          ░██████   ░████████       ░██         ░██               ░██     ░██  ░██  ░██  ░██           ░██ ░████   ░██
# ░██               ░██  ░██    ░██      ░██     ░█████     ░██████    ░█████████  ░█████████ ░██           ░██░██░██   ░██
# ░██          ░███████  ░██    ░██      ░██         ░██               ░██         ░██    ░██ ░██           ░████ ░██   ░██
# ░██         ░██   ░██  ░███   ░██      ░██   ░██   ░██               ░██         ░██    ░██  ░██   ░██     ░██ ░██    ░██
# ░██████████  ░█████░██ ░██░█████     ░██████  ░██████                ░██         ░██    ░██   ░██████       ░████   ░██████

# %% [markdown]
# # Exercícios sobre Exceções em Python
#
# Nos exercícios seguintes, utilize exceções para lidar com os casos de possíveis erros

# %% [markdown]
# ## Exercício 1
#
# Escreva uma função que recebe dois números e retorna a divisão do primeiro pelo segundo.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 2
#
# Escreva uma função que converte uma string para inteiro e retorna o valor. Se a conversão falhar, retorne None.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 3
#
# Escreva uma função que acede a um índice de uma lista fornecida. Se o índice não existir, retorne a mensagem "Índice inválido".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 4
#
# Escreva uma função que abre um ficheiro para leitura e retorna o seu conteúdo. Se o ficheiro não existir, retorne uma string com indicação do erro.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 5
#
# Escreva uma função que acede a uma chave de um dicionário. Se a chave não existir, retorne o valor "Chave não encontrada".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 6
#
# Escreva uma função que recebe uma lista de strings e as converte para inteiros. Retorne a lista de inteiros, ignorando valores que não possam ser convertidos.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 7
#
# Escreva uma função que divide dois números. Se a divisão for bem-sucedida, imprima "Operação realizada com sucesso". Em qualquer caso, imprima "Fim da função" no final.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 8
#
# Escreva uma função que recebe uma lista e um índice. Se o acesso for bem-sucedido, retorne o elemento e imprima "Acesso bem-sucedido". Se falhar, retorne None. Independentemente do resultado, imprima "Operação concluída".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 9
#
# Escreva uma função que tenta converter uma string para float. Se a conversão for bem-sucedida, retorne o dobro do valor. Se falhar, retorne 0.0.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 10
#
# Escreva uma função que recebe uma idade (inteiro). Se a idade for negativa, lance uma exceção ValueError com a mensagem "Idade não pode ser negativa".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 11
#
# Escreva uma função que valida um email. Se o email não contiver o símbolo '@', lance uma exceção ValueError com a mensagem "Email inválido".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 12
#
# Escreva uma função que recebe um número e calcula a sua raiz quadrada. Se o número for negativo, lance uma exceção apropriada.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 13
#
# Escreva uma função que recebe uma lista de números e retorna a média. Se a lista estiver vazia, lance uma exceção ValueError com a mensagem "Lista vazia".

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 14
#
# Crie uma exceção personalizada chamada `SaldoInsuficienteError`. Escreva uma função que simula um levantamento bancário e lança esta exceção se o saldo for insuficiente.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 15
#
# Crie uma exceção personalizada chamada `IdadeInvalidaError` que aceita uma mensagem personalizada. Escreva uma função que valida se uma idade está entre 0 e 150, lançando a exceção caso contrário.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 16
#
# Crie uma hierarquia de exceções personalizadas: `ErroValidacao` (classe base), `ErroNomeInvalido` e `ErroEmailInvalido` (classes derivadas). Escreva uma função que valida nome e email, lançando as exceções apropriadas.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 17
#
# Escreva uma função que processa uma lista de operações matemáticas (divisões). Para cada operação, capture exceções específicas (ZeroDivisionError, TypeError) e genéricas, registando os erros numa lista que deve ser retornada.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 18
#
# Crie uma exceção personalizada `ErroConexao` que armazena um código de erro e uma mensagem. Escreva uma função que simula uma conexão a um servidor e lança esta exceção com diferentes códigos conforme o tipo de falha.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 19
#
# Escreva um gestor de contexto (context manager) usando uma classe que abre e fecha um recurso. Implemente os métodos `__enter__` e `__exit__` para garantir que o recurso é sempre fechado, mesmo em caso de exceção.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 20
#
# Escreva uma função que processa dados de utilizadores (nome, idade, email). A função deve validar todos os campos, lançando exceções personalizadas específicas. Implemente também uma função de nível superior que chama a primeira e trata todas as exceções possíveis, registando-as adequadamente.

# %%
# Escreva o seu código aqui
