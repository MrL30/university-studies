# %% [markdown]
# # Lab 08a - PAC01: Programação Orientada a Objetos em Python

# %% [markdown]
# ## Parte 1: Criação da Classe BankAccount
#
# **Objetivo:**
# Crie um programa que faça a gestão de contas bancárias.
#
# **Requisitos:**
# - Deve criar uma classe `BankAccount`, que tem como variáveis de instância um valor de abertura e o nome do titular da conta.
# - Posteriormente, na sua função `main` crie duas instâncias da classe `BankAccount` (ou seja, crie duas "contas") e imprima na consola, para cada uma delas, o nome do titular e o saldo da conta.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Parte 2: Método de Acesso ao Saldo
#
# **Objetivo:**
# Adicione um método à classe `BankAccount` que lhe permita aceder ao saldo da conta bancária, sem utilizar a variável de instância da classe.
#
# **Requisitos:**
# - Na função `main` imprima os saldos das contas bancárias criadas a partir do método que criou, em vez de aceder à variável de instância.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Parte 3: Método de Depósito
#
# **Objetivo:**
# Implemente agora o método `deposit()` que permite depositar dinheiro nas contas.
#
# **Requisitos:**
# - Este método deve ter como parâmetro o valor que o utilizador quer depositar na conta.
# - Na função `main` faça depósitos de valores nas instâncias das contas bancárias criadas.
# - Através do método de consulta do saldo da conta, criado anteriormente, verifique que o dinheiro foi depositado com sucesso.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Parte 4: Método de Levantamento
#
# **Objetivo:**
# Implemente o método `withdraw()` que permite levantar dinheiro da conta.
#
# **Requisitos:**
# - Este método deve ter como parâmetro o valor que o utilizador quer levantar da conta.
# - **Atenção:** O utilizador não pode levantar mais dinheiro do que aquele que tem depositado.
# - Na função `main` faça levantamento de valores nas instâncias das contas bancárias criadas.
# - Através do método de consulta do saldo da conta, criado anteriormente, verifique que o dinheiro foi levantado com sucesso.
# - Teste se consegue levantar mais dinheiro do que está depositado.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Parte 5: Método de Transferência
#
# **Objetivo:**
# Implemente o método `transfer()` que permite transferir dinheiro entre duas contas bancárias.
#
# **Requisitos:**
# - Este método deve ter como parâmetro a conta para a qual o utilizador quer transferir o dinheiro e a quantia a transferir.
# - **Atenção:** O utilizador não pode transferir mais dinheiro do que aquele que tem depositado.
# - Na função `main` faça transferência de valores entre as contas bancárias criadas.
# - Através do método de consulta do saldo da conta, criado anteriormente, verifique que o dinheiro foi transferido com sucesso.
# - Teste se consegue transferir mais dinheiro do que está depositado.

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Parte 6: Otimização do Código
#
# **Questão para reflexão:**
#
# O método `withdraw()` e o método `transfer()` obrigam a que o utilizador não possa realizar as operações utilizando mais dinheiro do que aquele que tem depositado.
#
# **Qual será uma otimização possível a fazer no código?**
#
# *Dica: Pense em como evitar duplicação de código entre os dois métodos.*

# %%
# Escreva a sua resposta e implementação aqui
