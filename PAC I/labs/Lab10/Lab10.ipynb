# %% [raw]
# ░██                    ░██             ░██     ░████                 ░█████████     ░███      ░██████       ░████     ░██
# ░██                    ░██           ░████    ░██ ░██                ░██     ░██   ░██░██    ░██   ░██     ░██ ░██  ░████
# ░██          ░██████   ░████████       ░██   ░██ ░████               ░██     ░██  ░██  ░██  ░██           ░██ ░████   ░██
# ░██               ░██  ░██    ░██      ░██   ░██░██░██    ░██████    ░█████████  ░█████████ ░██           ░██░██░██   ░██
# ░██          ░███████  ░██    ░██      ░██   ░████ ░██               ░██         ░██    ░██ ░██           ░████ ░██   ░██
# ░██         ░██   ░██  ░███   ░██      ░██    ░██ ░██                ░██         ░██    ░██  ░██   ░██     ░██ ░██    ░██
# ░██████████  ░█████░██ ░██░█████     ░██████   ░████                 ░██         ░██    ░██   ░██████       ░████   ░██████

# %% [markdown]
# ## Exercício 1 - Criar e Escrever num Ficheiro de Texto
#
# **Objetivo:** Criar um ficheiro chamado `ola.txt` e escrever a mensagem "Olá, Mundo!".
#
# **Instruções:**
# - Use o modo `'w'` para abrir o ficheiro
# - Escreva a mensagem no ficheiro
# - Não se esqueça de fechar o ficheiro

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 2 - Ler um Ficheiro de Texto
#
# **Objetivo:** Ler o conteúdo do ficheiro `ola.txt` criado no exercício anterior e imprimi-lo.
#
# **Instruções:**
# - Use o modo `'r'` para abrir o ficheiro
# - Leia todo o conteúdo utilizando o método `.read()`
# - Imprima o conteúdo
# - Feche o ficheiro

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 3 - Usar Context Manager (with)
#
# **Objetivo:** Reescrever o Exercício 1 usando o context manager `with` para garantir o fecho automático do ficheiro.
#
# **Instruções:**
# - Use a estrutura `with open(...) as f:`
# - Crie um ficheiro `mensagem.txt`
# - Escreva 3 linhas de texto diferentes

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 4 - Adicionar Texto a um Ficheiro Existente
#
# **Objetivo:** Adicionar novas linhas ao ficheiro `mensagem.txt` sem apagar o conteúdo existente.
#
# **Instruções:**
# - Use o modo `'a'` (append)
# - Adicione 2 novas linhas ao ficheiro
# - Leia e imprima todo o conteúdo do ficheiro para verificar

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 5 - Ler Ficheiro Linha a Linha
#
# **Objetivo:** Ler o ficheiro `mensagem.txt` linha a linha e numerar cada linha ao imprimi-la.
#
# **Instruções:**
# - Abra o ficheiro em modo leitura
# - Use um loop para ler cada linha
# - Imprima cada linha com o formato: "Linha 1: conteúdo"
# - Use `.readlines()` ou itere diretamente sobre o objeto ficheiro

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 6 - Trabalhar com Ficheiros Binários
#
# **Objetivo:** Criar um ficheiro binário com uma lista de números inteiros e depois lê-lo.
#
# **Instruções:**
# - Crie uma lista de números: `[10, 20, 30, 40, 50]`
# - Use o módulo `pickle` para serializar a lista (pesquise na documentação do módulo como o pode utilizar)
# - Grave num ficheiro `numeros.bin` em modo binário (`'wb'`)
# - Leia o ficheiro de volta em modo `'rb'` e imprima a lista

# %%
import pickle

# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 7 - Modo de Leitura e Escrita (r+)
#
# **Objetivo:** Usar o modo `'r+'` para ler e modificar um ficheiro existente.
#
# **Instruções:**
# - Crie um ficheiro `dados.txt` com o texto "Python é fixe"
# - Abra o ficheiro em modo `'r+'`
# - Leia o conteúdo atual
# - Posicione o cursor no início com `.seek(0)`
# - Escreva "Java também é" (observe o que acontece)
# - Leia e imprima o resultado final

# %%
# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 8 - Copiar um Ficheiro Binário
#
# **Objetivo:** Criar uma função que copie um ficheiro binário (ex: imagem) byte a byte.
#
# **Instruções:**
# - Crie primeiro um ficheiro binário de teste com alguns bytes
# - Escreva uma função `copiar_ficheiro(origem, destino)`
# - A função deve ler o ficheiro origem em blocos de 1024 bytes
# - Escreva cada bloco no ficheiro destino
# - Teste a função e verifique se os ficheiros são idênticos

# %%
# Escreva o seu código aqui

def copiar_ficheiro(origem, destino):
    pass  # Implemente aqui

# %% [markdown]
# ## Exercício 9 - Processar um Ficheiro CSV
#
# **Objetivo:** Criar, escrever e ler um ficheiro CSV com dados de estudantes.
#
# **Instruções:**
# - Crie um ficheiro `estudantes.csv`
# - Escreva um cabeçalho: "Nome,Idade,Nota"
# - Adicione pelo menos 5 estudantes com dados diferentes
# - Leia o ficheiro e calcule a média das notas
# - Imprima o estudante com a nota mais alta
# - Use o módulo `csv` do Python

# %%
import csv

# Escreva o seu código aqui

# %% [markdown]
# ## Exercício 10 - Tratamento de Erros e Gestão de Ficheiros
#
# **Objetivo:** Criar uma função que leia um ficheiro JSON
#
# **Instruções:**
# - Crie uma função `ler_configuracao(nome_ficheiro)`
# - A função deve tentar abrir e ler um ficheiro JSON

# %%
import json

# Escreva o seu código aqui

def ler_configuracao(nome_ficheiro):
    pass  # Implemente aqui
