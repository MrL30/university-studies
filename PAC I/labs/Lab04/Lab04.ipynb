# %% [raw]
#  __                  __               ______   __    __                      _______    ______    ______
# /  |                /  |             /      \ /  |  /  |                    /       \  /      \  /      \
# $$ |        ______  $$ |____        /$$$$$$  |$$ |  $$ |                    $$$$$$$  |/$$$$$$  |/$$$$$$  |
# $$ |       /      \ $$      \       $$$  \$$ |$$ |__$$ |       ______       $$ |__$$ |$$ |__$$ |$$ |  $$/
# $$ |       $$$$$$  |$$$$$$$  |      $$$$  $$ |$$    $$ |      /      |      $$    $$/ $$    $$ |$$ |
# $$ |       /    $$ |$$ |  $$ |      $$ $$ $$ |$$$$$$$$ |      $$$$$$/       $$$$$$$/  $$$$$$$$ |$$ |   __
# $$ |_____ /$$$$$$$ |$$ |__$$ |      $$ \$$$$ |      $$ |                    $$ |      $$ |  $$ |$$ \__/  |
# $$       |$$    $$ |$$    $$/       $$   $$$/       $$ |                    $$ |      $$ |  $$ |$$    $$/
# $$$$$$$$/  $$$$$$$/ $$$$$$$/         $$$$$$/        $$/                     $$/       $$/   $$/  $$$$$$/

# %% [markdown]
# # Exercício 01
#
# ## Função range()
#
# Escreva um programa que receba dois números inteiros. O programa deve imprimir todos os números no intervalo entre o número inicial e o número final.
#
#
# 1. Regras:
#
# * Se o número inicial for menor que o número final, imprima os números em ordem crescente.
# * Se o número inicial for maior que o número final, imprima os números em ordem decrescente.
# * O programa deve garantir que o número final seja incluído na sequência impressa.
#
# 2. Dicas:
#
# * Utilize a função range() para criar uma sequência de números.
# * Para ordem decrescente, lembre-se de passar um terceiro argumento para o range().

# %% [markdown]
# ```python
# # Exemplo de execução do programa
#
# Digite o número inicial: 3
# Digite o número final: 8
# Resultado: 3, 4, 5, 6, 7, 8
#
# Digite o número inicial: 8
# Digite o número final: 3
# Resultado: 8, 7, 6, 5, 4, 3
# ```

# %% [markdown]
# # Exercício 02
#
# ## Gerir uma lista de IPs
#
# Crie uma lista de endereços IP.
# Depois utilize os ciclos for e while para imprimir os IPs na consola.
#
# Dicas:
# * para criar uma lista vazia em python pode utilizar a sintaxe `list = []`;
# * pode adicionar elementos à lista recorrendo à função `append()` com a seguinte sintaxe: `list.append('192.168.1.1')`;

# %%
# your code here

# %% [markdown]
# # Exercício 03
#
# ## String Slicing
#
# Escreva um pequeno script que receba o nome completo de um utilizador e separe o primeiro e o último nome.
# Por fim imprima o primeiro nome e apelido na consola.
#
# Dicas:
# * Pesquise um pouco na internet sobre o funcionamento da função split;
# * Por defeito, se nenhum argumento for passado à função `split()`, o separador considerado é o espaço entre palavras;
# * A função `split()`, quando retorna o resultado, devolve uma lista;

# %% [markdown]
# # Exercício 04
#
# ## Encontrar a temperatura máxima
#
# Dada a seguinte lista de temperaturas, encontre a temperatura máxima e imprima-a na consola.

# %%
# your code here

# %% [markdown]
# # Exercício 05
#
# ## Somar elementos numa lista
#
# Dada a seguinte lista, imprima na consola a soma de todos os seus elementos.

# %%
# list with numbers
numeros_inteiros = [i for i in range(1, 21)]

# your code below this line

# %% [markdown]
# # Exercício 06
#
# ## imprimir a pirâmide do Mário
#
# Escreva um programa que imprima na consola uma das pirâmides do jogo super mario.

# %%
#  expected result

       #
      ##
     ###
    ####
   #####
  ######
########

# your code below this line

# %% [markdown]
# # Exercício 07
#
# ## Programa de ataque a passwords - brute force
#
# Escreva um programa que tente adivinhar passwords de uma determinada lista.
#
# Objetivo:
# * escreva um programa que continuamente solicita a introdução de passwords e verifica se a password introduzida existe na lista de passwords.
# * Caso a password introduzida exista na lista, o programa deve terminar a sua execução e imprimir a password na consola
#
# ```python
# # Brute force password guessing (simple example)
# passwords = ['123456', 'password', 'letmein', 'admin']
#
# for password in passwords:
#     print(f"Trying password: {password}")
#     # Simulate password check
#     if password == 'admin':
#         print("Password found: admin")
#         break
# ```
#
# ```

# %% [markdown]
# # Exercício 08
#
# Responda às seguintes questões:
#
# 1. Qual a importância desta capacidade de repetir ações na cibersegurança (por exemplo em ataques de força bruta ou scans)?
# 2. Vantagens e desvantagens?

# %% [markdown]
# # Exercício 09
#
# ## Simulador de Força Bruta
#
# Neste exercício, você irá simular um ataque de força bruta simples para tentar descobrir um pin de 4 dígitos.
#
# O programa irá solicitar que o utilizador defina uma senha, e irá "testar" todas as combinações possíveis até encontrar a senha correta.
#
# 1. Regras:
# * O utilizador deve definir uma senha de 4 números (um número entre 0000 e 9999).
# * O programa deve simular um ataque de força bruta, testando todas as combinações possíveis de 0000 até 9999.
# * Quando o programa encontrar o pin definido pelo utilizador, deve exibir uma mensagem indicando o número de tentativas necessárias.
# * O programa deve parar a procura assim que encontrar o pin correto.
#
# 2. Dicas:
# * Utilize uma função para gerar números.
# * Use a palavra reservada break para interromper o loop quando o pin for encontrado. Pesquise na internet qual a melhor forma de utilizar esta funcionalidade da linguagem python.
#
#
# 3. Exemplo de execução
#
# ```python
# Defina a sua senha (4 dígitos): 3456
# Tentando quebrar a senha...
# Tentativa 1: 0000
# Tentativa 2: 0001
# Tentativa 3: 0002
# ...
# Tentativa 3457: 3456
# Senha encontrada! Foram necessárias 3457 tentativas.
# ```

# %%
# your code here

# %% [markdown]
# # Exercício 10
#
# ## Criar um gerador de passwords e passphrases
#
# Implemente um programa que crie paswords e passphrases para o utilizador.
#
# 1. Regras:
# + O programa deve perguntar se o utilizador quer gerar uma password ou uma passphrase.
# + Se o utilizador quiser uma password, deve perguntar o número de caracteres que a password deve ter.
# + Deve perguntar também se a password deve ter números e/ou caracteres especiais.
# + Caso o utilizador queira uma passphrase, deve gerar uma passphrase utilizando no mínimo 4 palavras e no máximo 8.
#
# 2. Exemplo de execução:
#
#     * exemplo para password
#        ```python
#         Desejar criar uma password ou passphrase?
#         $ password
#
#         Quantos caracteres deve ter a password?
#         $ 14
#
#         A password deve ter números?
#         $ sim
#
#         A password deve ter caracteres especiais?
#         $ sim
#
#         A sua password é: TdTEIn7833%%ds
#        ```
#
#    * exemplo para passphrase
#        ```python
#        Desejar criar uma password ou passphrase?
#         $ passphrase
#
#         Quantas palavras deve ter a passphrase (entre 4 e 8)?
#         $ 4
#
#         A sua passphrase é: serenity-videre-eternal-lex
#        ```

# %%
letters = [chr(i) for i in range(65, 91)]
numbers = [str(i) for i in range(10)]
symbols = ['!', '@', '#', '$', '%', '^', '&', '*', '(', ')', '-', '_', '=', '+', '[', ']', '{', '}', ';', ':', ',', '.', '/', '<', '>', '?']
words = [
    "valor", "aqua", "silent", "fortis", "liberty", "quantum", "lumen", "matrix",
    "summit", "terra", "vitalis", "nexus", "vertex", "flumen", "momentum", "clarus",
    "arcane", "vastus", "plenum", "inspire", "veritas", "chrono", "lucis", "unity",
    "ardor", "inceptum", "solaris", "primus", "natura", "invenio", "cogito", "sapiens",
    "focus", "virtus", "noble", "honor", "celer", "mystic", "aether", "ethos",
    "fidelis", "paradox", "stella", "magnus", "profectus", "pax", "ignis", "axis",
    "fluxus", "pura", "noctis", "serenity", "legacy", "vivid", "secure", "vivamus",
    "aureus", "sphere", "vector", "infinitus", "aeternum", "scientia", "exemplar",
    "ferox", "alpha", "venus", "pulse", "lux", "omnia", "caelum", "sapientia", "spiritus",
    "tempus", "aegis", "ignotus", "lex", "dynamic", "videre", "aurora", "ascend",
    "sensus", "photon", "fortuna", "relic", "virtue", "focus", "venatus", "levitas",
    "motus", "lucifer", "callidus", "crescendo", "firma", "hero", "constantia", "eternal",
    "celeritas", "creator", "venio", "circulus", "echo", "metamorph", "ordo", "radius"
]


# Your code below this line

# %% [markdown]
# # Exercício 11
#
# ## Calculadora simples
#
# Recorrendo à utilização de funções (uma função por operação), escreva um programa que simule uma calculadora simples.
#
# Regras:
# * O programa deve solicitar ao utilizador dois números e uma operação (adição, subtração, multiplicação ou divisão)
# * O resultado da operação é mostrado na consola

# %%
# your code here

# %% [markdown]
# # Exercício 12
#
# ## Contagem de vogais
#
# Utilizando funções, escreva um programa que conte o número de vogais numa palavra introduzida pelo utilizador.

# %%
# your code here

# %% [markdown]
# # Exercício 13
#
# ## Contagem de palavras
#
# Recorrendo a funções, escreva um programa que conte o número de palavras numa frase introduzida pelo utilizador.

# %%
# your code here

# %% [markdown]
# # Exercício 14
#
# ## Verificador de ano bisexto
#
# Escreva um programa que verifique se um ano introduzido pelo utilizador é bissexto ou não.
#
# Dicas
#
# Para calcular se um ano é bisexto ou não, utilizam-se as seguintes operações matemáticas:
# * Se a divisão do ano por 4 tiver resto 0, **e** se a divisão do ano por 100 tiver resto diferente de 0 **ou** se a divisão do ano por 400 tiver resto 0

# %%
# your code here
