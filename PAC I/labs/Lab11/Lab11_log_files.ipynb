# %% [markdown]
# # Exercícios de Análise de Logs em Python (1-10)
#
# Este notebook contém 10 exercícios práticos de dificuldade crescente.
# Certifique-se de que todos os ficheiros de log auxiliares estão na mesma pasta.

# %% [markdown]
# ## Exercício 1: Contagem Básica de Status Codes
# **Ficheiro:** `server_access.log`
# Objetivo: Conte quantas vezes cada código de status HTTP aparece.

# %%
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 2: Filtragem e Parsing de Strings
# **Ficheiro:** `app_errors.log`
# Objetivo: Extraia apenas as mensagens das linhas com `ERROR`.

# %%
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 3: Análise Temporal com Pandas
# **Ficheiro:** `user_sessions.csv`
# Objetivo: Calcule a duração média das sessões (logout - login).

# %%
import pandas as pd
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 4: Dados Estruturados (JSON Lines)
# **Ficheiro:** `api_requests.json`
# Objetivo: Encontre o `endpoint` com maior tempo de resposta médio.

# %%
import json
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 5: Detecção de Anomalias (Regex)
# **Ficheiro:** `firewall.log`
# Objetivo: Use regex para achar IPs com mais de 5 falhas de autenticação.

# %%
import re
from collections import Counter
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 6: Agregação de Múltiplos Ficheiros
#
# **Ficheiros:** `daily_traffic_part1.log` e `daily_traffic_part2.log`
#
# **Objetivo:** Ambos os ficheiros contêm dados no formato `timestamp,bytes`. Leia ambos os ficheiros e calcule o total de bytes transferidos (soma de todas as linhas de ambos os ficheiros). Não use bibliotecas externas como pandas, apenas Python puro.

# %%
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 7: Parsing Avançado de Strings (Sem Regex)
#
# **Ficheiro:** `config_updates.log`
#
# **Objetivo:** O log tem o formato `timestamp | user:Nome | action:Acao | key:Chave`. Sem usar expressões regulares (use `split`, `find`, etc.), descubra qual utilizador realizou uma ação `UPDATE` na chave `MAX_RETRIES`. Imprima o nome desse utilizador.

# %%
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 8: Correlação de Dados (Join com Pandas)
#
# **Ficheiros:** `products.csv` e `sales.log`
#
# **Objetivo:** O ficheiro `sales.log` (formato CSV) contém vendas (`product_id,quantity`). O ficheiro `products.csv` contém detalhes dos produtos (`id,name,price`). Carregue ambos em DataFrames, faça um merge/join e calcule o valor total de vendas (preço * quantidade) para cada nome de produto.

# %%
import pandas as pd

# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 9: Análise de Sequência (Lógica de Estado)
#
# **Ficheiro:** `auth_attempts.log`
#
# **Objetivo:** O ficheiro contém linhas `Usuario STATUS` (ex: `userA SUCCESS`). Sem usar regex, percorra o ficheiro e identifique se algum utilizador teve **3 falhas consecutivas** (`FAILURE`). Imprima o nome do utilizador caso isso aconteça.

# %%
# Escreve a tua solução aqui

# %% [markdown]
# ## Exercício 10: Séries Temporais e Resampling
#
# **Ficheiro:** `server_metrics.csv`
#
# **Objetivo:** O ficheiro contém métricas de servidor (`timestamp,cpu_usage`). Converta a coluna de timestamp para datetime. Agrupe os dados por **hora** (resampling) e calcule a média de uso de CPU para cada hora. Identifique qual a hora do dia com a maior média de CPU.

# %%
import pandas as pd

# Escreve a tua solução aqui
